# %%
<!DOCTYPE html>
<html>
  <head>
    <meta charset="utf-8" />
    <title>CNT Parallax Crucible</title>
    <meta name="viewport" content="width=device-width, initial-scale=1" />
    <!-- React via CDN (dev) -->
    <script crossorigin src="https://unpkg.com/react@18/umd/react.development.js"></script>
    <script crossorigin src="https://unpkg.com/react-dom@18/umd/react-dom.development.js"></script>
    <script crossorigin src="https://unpkg.com/@babel/standalone/babel.min.js"></script>
    <style>html,body,#root{height:100%;margin:0} .center{display:grid;place-items:center;background:#fff;height:100%}</style>
  </head>
  <body>
    <div id="root" class="center"></div>
    <script type="text/babel">
      // Paste the entire component from the canvas here (change 'export default' to just 'function CNTParallaxCrucible() { ... }')
      // and include helpers above it. Then render:

      // ==== BEGIN PASTE (short wrapper only) ====
      // (Paste the full code from the canvas replacing this block.)
      // ==== END PASTE ====

      const root = ReactDOM.createRoot(document.getElementById("root"));
      root.render(<CNTParallaxCrucible />);
    </script>
  </body>
</html>
# Out:
#   Cell In[1], line 1
#     <!DOCTYPE html>
#     ^
# SyntaxError: invalid syntax
