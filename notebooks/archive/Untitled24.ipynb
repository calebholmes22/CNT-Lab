# %%
import sys, os, pandas
print(sys.executable)
print("CNT_LAB_DIR =", os.getenv("CNT_LAB_DIR"))
print("pandas version =", pandas.__version__)
# Out:
# C:\Users\caleb\CNT_Lab\.venv\Scripts\python.exe
# CNT_LAB_DIR = E:\CNT
# pandas version = 2.3.3
