# %% [markdown]
# # CNT Lab — Setup Template
# Run the next cell to initialize the environment for this notebook.

# %%
import cntlab as cl
cl.nb.init()
# Out:
# [2025-10-08 20:17:46,086] INFO cntlab: CNTLab notebook initialized
# [2025-10-08 20:17:46,087] INFO cntlab: CNT Paths(root=C:\Users\caleb\CNT_Lab)
# → CNTLab ready.
#    Root: C:\Users\caleb\CNT_Lab
#    Figures: C:\Users\caleb\CNT_Lab\artifacts\figures
#    Tables: C:\Users\caleb\CNT_Lab\artifacts\tables
#    Metrics: C:\Users\caleb\CNT_Lab\artifacts\metrics
# {'root': 'C:\\Users\\caleb\\CNT_Lab',
#  'figures': 'C:\\Users\\caleb\\CNT_Lab\\artifacts\\figures',
#  'tables': 'C:\\Users\\caleb\\CNT_Lab\\artifacts\\tables',
#  'metrics': 'C:\\Users\\caleb\\CNT_Lab\\artifacts\\metrics'}

# %%
# === CNT Lab — One-Cell Migrator ============================================
# Scans source folders, classifies files by extension, copies or moves them into
# CNT_LAB_DIR/artifacts/* (figures, tables, metrics, models, blobs), and logs each
# entry into the manifest with sha256 + tags inferred from path components.
#
# Usage:
# 1) Adjust SOURCE_ROOTS below (defaults include your Windows path).
# 2) Set DRY_RUN=False to actually copy/move.
# 3) Set MODE to "copy" (default) or "move".
# 4) Re-run as needed; duplicates (same hash) are skipped.
# ============================================================================

import os, re, json, shutil, hashlib
from pathlib import Path
import cntlab as cl

# --- CONFIG -----------------------------------------------------------------
# Add/adjust any roots you want to sweep:
SOURCE_ROOTS = [
    Path(r"C:\Users\caleb\cnt_genome"),
    Path.home() / "cnt_genome",  # fallback if you run elsewhere
]

# Dry-run prints what it *would* do without touching files:
DRY_RUN = False         # <-- set to False to perform the migration
MODE    = "copy"       # "copy" or "move"

# Skip these dirs by name anywhere in the tree:
EXCLUDE_DIRS = {".git", ".hg", ".svn", "__pycache__", ".ipynb_checkpoints", ".venv", "env", "venv", "node_modules"}

# File classification (extend as you wish):
IMG_EXTS    = {".png", ".jpg", ".jpeg", ".svg", ".tif", ".tiff", ".gif", ".pdf"}
TABLE_EXTS  = {".csv", ".tsv", ".parquet", ".feather", ".xls", ".xlsx"}
METRIC_EXTS = {".json", ".yaml", ".yml", ".toml", ".jsonl"}
MODEL_EXTS  = {".pt", ".pth", ".ckpt", ".h5", ".hdf5", ".joblib", ".pkl", ".sav", ".onnx", ".pb", ".tflite", ".npz"}

# Tag helpers: words to tag if they appear in the path (case-insensitive)
KEYWORDS = ["kuramoto", "ising", "genome", "atlas", "eeg", "granger", "topo", "drift", "resonance", "fss", "cnt", "mega"]

# ----------------------------------------------------------------------------
P = cl.P
logger = cl.log.get_logger("migrate")

def sha256(path: Path) -> str:
    h = hashlib.sha256()
    with path.open("rb") as f:
        for chunk in iter(lambda: f.read(1024 * 1024), b""):
            h.update(chunk)
    return h.hexdigest()

def load_known_hashes() -> set[str]:
    mf = P.manifests / "manifest.jsonl"
    known = set()
    if mf.exists():
        with mf.open("r", encoding="utf-8") as f:
            for line in f:
                try:
                    rec = json.loads(line)
                except json.JSONDecodeError:
                    continue
                if rec.get("sha256"):
                    known.add(rec["sha256"])
    return known

def classify(ext: str) -> str:
    e = ext.lower()
    if e in IMG_EXTS:   return "figure"
    if e in TABLE_EXTS: return "table"
    if e in METRIC_EXTS:return "metrics"
    if e in MODEL_EXTS: return "model"
    return "blob"

def slug(s: str) -> str:
    s = s.strip().lower()
    s = re.sub(r"[^a-z0-9]+", "-", s)
    return s.strip("-")

def infer_tags(rel_parts: list[str], ext: str) -> list[str]:
    tags = {"migrated", ext.lstrip(".").lower()}
    # include up to first 3 directory names as coarse tags
    for p in rel_parts[:3]:
        if not p: 
            continue
        tags.add(slug(p))
    # keyword hits
    joined = "/".join(rel_parts).lower()
    for k in KEYWORDS:
        if k in joined:
            tags.add(k)
    return sorted(t for t in tags if t)

def ensure_dirs():
    for d in [P.figures, P.tables, P.metrics, P.models, P.artifacts, P.manifests, P.logs]:
        d.mkdir(parents=True, exist_ok=True)

def target_dir_for(kind: str) -> Path:
    return {
        "figure":  P.figures,
        "table":   P.tables,
        "metrics": P.metrics,
        "model":   P.models,
        "blob":    P.artifacts,
    }[kind]

def migrate():
    ensure_dirs()
    known = load_known_hashes()
    stats = {"scanned":0, "skipped_dupe":0, "migrated":0, "errors":0}
    by_kind = {"figure":0, "table":0, "metrics":0, "model":0, "blob":0}

    # Prepare source roots that exist
    roots = [r for r in SOURCE_ROOTS if r.exists()]
    if not roots:
        print("No SOURCE_ROOTS exist. Adjust paths and retry.")
        return

    for root in roots:
        print(f"Scanning: {root}")
        for dirpath, dirnames, filenames in os.walk(root):
            # strip excluded
            dirnames[:] = [d for d in dirnames if d not in EXCLUDE_DIRS]
            base = Path(dirpath)
            rel_base = base.relative_to(root) if base != root else Path("")

            for fn in filenames:
                src = base / fn
                stats["scanned"] += 1

                ext = src.suffix.lower()
                kind = classify(ext)
                rel_parts = [p for p in rel_base.parts if p]
                tags = infer_tags(rel_parts + [src.stem], ext)
                try:
                    h = sha256(src)
                except Exception as e:
                    logger.error(f"hash fail: {src} | {e}")
                    stats["errors"] += 1
                    continue

                if h in known:
                    stats["skipped_dupe"] += 1
                    continue

                # Deterministic-ish rename using content hash prefix:
                short = h[:8]
                tgt_dir = target_dir_for(kind)
                tgt_name = f"migrated__{slug(src.stem)}__{short}{ext}"
                dst = tgt_dir / tgt_name

                msg = f"{MODE.upper():4} {kind:7} {src}  ->  {dst}   tags={tags}"
                if DRY_RUN:
                    print("[DRY]", msg)
                else:
                    try:
                        dst.parent.mkdir(parents=True, exist_ok=True)
                        if MODE == "move":
                            shutil.move(str(src), str(dst))
                        else:
                            shutil.copy2(str(src), str(dst))
                        # Log to manifest
                        cl.manifest.log_artifact(dst, kind=kind, tags=tags, meta={"source": str(src)})
                        stats["migrated"] += 1
                        by_kind[kind] += 1
                        known.add(h)
                        logger.info(msg)
                    except Exception as e:
                        logger.error(f"migrate fail: {src} -> {dst} | {e}")
                        stats["errors"] += 1

    print("\n== MIGRATION SUMMARY ==")
    for k,v in stats.items(): print(f"{k:14}: {v}")
    if not DRY_RUN:
        print("By kind:", by_kind)
    print("Manifest:", (P.manifests / "manifest.jsonl"))

migrate()
# Out:
# [2025-10-08 20:21:01,279] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNTAlpha.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cntalpha__9c54888e.ipynb   tags=['cnt', 'cntalpha', 'ipynb', 'migrated']
# [2025-10-08 20:21:01,307] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNTGenome  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cntgenome__39ac6c67   tags=['cnt', 'cntgenome', 'genome', 'migrated']
# [2025-10-08 20:21:01,321] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNTGenome.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cntgenome__703ea35e.ipynb   tags=['cnt', 'cntgenome', 'genome', 'ipynb', 'migrated']
# [2025-10-08 20:21:01,335] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_3D_GenomicField_clean.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-3d-genomicfield-clean__44829feb.ipynb   tags=['cnt', 'cnt-3d-genomicfield-clean', 'ipynb', 'migrated']
# [2025-10-08 20:21:01,351] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_3D_GenomicField_UPGRADE.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-3d-genomicfield-upgrade__2fd0afe3.ipynb   tags=['cnt', 'cnt-3d-genomicfield-upgrade', 'ipynb', 'migrated']
# Scanning: C:\Users\caleb\cnt_genome
# [2025-10-08 20:22:14,330] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_CognitiveAlphabet_Bundle.zip  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-cognitivealphabet-bundle__cc7e149f.zip   tags=['cnt', 'cnt-cognitivealphabet-bundle', 'migrated', 'zip']
# [2025-10-08 20:22:14,347] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_colored_3D_field.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-colored-3d-field__ab11c5a3.png   tags=['cnt', 'cnt-colored-3d-field', 'migrated', 'png']
# [2025-10-08 20:22:14,373] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\CNT_edges.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__cnt-edges__204dcd26.csv   tags=['cnt', 'cnt-edges', 'csv', 'migrated']
# [2025-10-08 20:22:14,385] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\CNT_genomic_modules.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__cnt-genomic-modules__2ee69350.csv   tags=['cnt', 'cnt-genomic-modules', 'csv', 'migrated']
# [2025-10-08 20:22:14,420] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_genomic_network_3D.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-genomic-network-3d__d12de409.html   tags=['cnt', 'cnt-genomic-network-3d', 'html', 'migrated']
# [2025-10-08 20:22:14,430] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_genomic_network_3D.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-genomic-network-3d__3b6fd167.png   tags=['cnt', 'cnt-genomic-network-3d', 'migrated', 'png']
# [2025-10-08 20:22:14,501] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_genomic_network_3D_modules.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-genomic-network-3d-modules__2d6d458d.html   tags=['cnt', 'cnt-genomic-network-3d-modules', 'html', 'migrated']
# [2025-10-08 20:22:14,516] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_genomic_network_3D_modules.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-genomic-network-3d-modules__59f101d1.png   tags=['cnt', 'cnt-genomic-network-3d-modules', 'migrated', 'png']
# [2025-10-08 20:22:14,526] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_Glyph_Raytracing.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-glyph-raytracing__199260de.ipynb   tags=['cnt', 'cnt-glyph-raytracing', 'ipynb', 'migrated']
# [2025-10-08 20:22:14,537] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_Glyph_Raytracing_Interactive.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-glyph-raytracing-interactive__7f550314.ipynb   tags=['cnt', 'cnt-glyph-raytracing-interactive', 'ipynb', 'migrated']
# [2025-10-08 20:22:14,541] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_Granger_Crash_Test.pdf  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-granger-crash-test__15d8f320.pdf   tags=['cnt', 'cnt-granger-crash-test', 'granger', 'migrated', 'pdf']
# [2025-10-08 20:22:14,547] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_Granger_Crash_Test_Report.txt  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-granger-crash-test-report__c89388fc.txt   tags=['cnt', 'cnt-granger-crash-test-report', 'granger', 'migrated', 'txt']
# [2025-10-08 20:22:14,596] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_Hubble_Tension_DualAttack.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-hubble-tension-dualattack__364ed736.ipynb   tags=['cnt', 'cnt-hubble-tension-dualattack', 'ipynb', 'migrated']
# [2025-10-08 20:22:14,609] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_Hubble_Tension_DualAttack_PATCHED.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-hubble-tension-dualattack-patched__6032b518.ipynb   tags=['cnt', 'cnt-hubble-tension-dualattack-patched', 'ipynb', 'migrated']
# [2025-10-08 20:22:14,621] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_Hubble_Tension_DualAttack_v2.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-hubble-tension-dualattack-v2__a70a3e59.ipynb   tags=['cnt', 'cnt-hubble-tension-dualattack-v2', 'ipynb', 'migrated']
# [2025-10-08 20:22:14,656] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_module_0.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-module-0__5002616f.html   tags=['cnt', 'cnt-module-0', 'html', 'migrated']
# [2025-10-08 20:22:14,667] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_module_0.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-module-0__0c1ea628.png   tags=['cnt', 'cnt-module-0', 'migrated', 'png']
# [2025-10-08 20:22:14,701] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_module_1.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-module-1__b52c7662.html   tags=['cnt', 'cnt-module-1', 'html', 'migrated']
# [2025-10-08 20:22:14,710] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_module_1.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-module-1__56898e72.png   tags=['cnt', 'cnt-module-1', 'migrated', 'png']
# [2025-10-08 20:22:14,743] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_module_10.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-module-10__28410db0.html   tags=['cnt', 'cnt-module-10', 'html', 'migrated']
# [2025-10-08 20:22:14,754] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_module_10.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-module-10__21ae172e.png   tags=['cnt', 'cnt-module-10', 'migrated', 'png']
# [2025-10-08 20:22:14,787] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_module_11.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-module-11__41456511.html   tags=['cnt', 'cnt-module-11', 'html', 'migrated']
# [2025-10-08 20:22:14,799] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_module_11.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-module-11__937286c0.png   tags=['cnt', 'cnt-module-11', 'migrated', 'png']
# [2025-10-08 20:22:14,845] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_module_2.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-module-2__82e76fed.html   tags=['cnt', 'cnt-module-2', 'html', 'migrated']
# [2025-10-08 20:22:14,854] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_module_2.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-module-2__9045c239.png   tags=['cnt', 'cnt-module-2', 'migrated', 'png']
# [2025-10-08 20:22:14,898] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_module_3.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-module-3__6349cc8a.html   tags=['cnt', 'cnt-module-3', 'html', 'migrated']
# [2025-10-08 20:22:14,908] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_module_3.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-module-3__de8b9e04.png   tags=['cnt', 'cnt-module-3', 'migrated', 'png']
# [2025-10-08 20:22:14,947] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_module_4.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-module-4__9d46da0d.html   tags=['cnt', 'cnt-module-4', 'html', 'migrated']
# [2025-10-08 20:22:14,959] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_module_4.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-module-4__a1dcbf67.png   tags=['cnt', 'cnt-module-4', 'migrated', 'png']
# [2025-10-08 20:22:15,019] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_module_5.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-module-5__2c4dba4b.html   tags=['cnt', 'cnt-module-5', 'html', 'migrated']
# [2025-10-08 20:22:15,034] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_module_5.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-module-5__abaa8f00.png   tags=['cnt', 'cnt-module-5', 'migrated', 'png']
# [2025-10-08 20:22:15,066] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_module_6.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-module-6__abe7fd49.html   tags=['cnt', 'cnt-module-6', 'html', 'migrated']
# [2025-10-08 20:22:15,081] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_module_6.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-module-6__812b7e64.png   tags=['cnt', 'cnt-module-6', 'migrated', 'png']
# [2025-10-08 20:22:15,114] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_module_7.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-module-7__eea9d998.html   tags=['cnt', 'cnt-module-7', 'html', 'migrated']
# [2025-10-08 20:22:15,126] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_module_7.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-module-7__77169c09.png   tags=['cnt', 'cnt-module-7', 'migrated', 'png']
# [2025-10-08 20:22:15,174] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_module_8.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-module-8__808000dd.html   tags=['cnt', 'cnt-module-8', 'html', 'migrated']
# [2025-10-08 20:22:15,184] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_module_8.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-module-8__0abef51b.png   tags=['cnt', 'cnt-module-8', 'migrated', 'png']
# [2025-10-08 20:22:15,218] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_module_9.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-module-9__c2699330.html   tags=['cnt', 'cnt-module-9', 'html', 'migrated']
# [2025-10-08 20:22:15,228] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_module_9.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-module-9__2d991a96.png   tags=['cnt', 'cnt-module-9', 'migrated', 'png']
# [2025-10-08 20:22:15,231] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_module_gallery.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-module-gallery__2caa57a9.html   tags=['cnt', 'cnt-module-gallery', 'html', 'migrated']
# [2025-10-08 20:22:15,239] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_module_heatmap.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-module-heatmap__1ccb7ea4.png   tags=['cnt', 'cnt-module-heatmap', 'migrated', 'png']
# [2025-10-08 20:22:15,243] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\CNT_module_index.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__cnt-module-index__bf5df735.csv   tags=['cnt', 'cnt-module-index', 'csv', 'migrated']
# [2025-10-08 20:22:15,278] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_module_lens.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-module-lens__430266d5.html   tags=['cnt', 'cnt-module-lens', 'html', 'migrated']
# [2025-10-08 20:22:15,287] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_module_lens.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-module-lens__e24ebc9d.png   tags=['cnt', 'cnt-module-lens', 'migrated', 'png']
# [2025-10-08 20:22:15,298] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_module_map.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-module-map__da38aabb.png   tags=['cnt', 'cnt-module-map', 'migrated', 'png']
# [2025-10-08 20:22:15,317] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\CNT_nodes_3D.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__cnt-nodes-3d__75c2e255.csv   tags=['cnt', 'cnt-nodes-3d', 'csv', 'migrated']
# [2025-10-08 20:22:15,350] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_one_field_atlas.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-one-field-atlas__0d4bf995.html   tags=['atlas', 'cnt', 'cnt-one-field-atlas', 'html', 'migrated']
# [2025-10-08 20:22:15,363] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_one_field_atlas.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-one-field-atlas__617609fb.png   tags=['atlas', 'cnt', 'cnt-one-field-atlas', 'migrated', 'png']
# [2025-10-08 20:22:15,381] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\cnt_proof_out.rar  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__cnt-proof-out__19f2fc73.rar   tags=['cnt', 'cnt-proof-out', 'migrated', 'rar']
# [2025-10-08 20:22:15,386] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\CNT_top_bridges.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__cnt-top-bridges__cb125936.csv   tags=['cnt', 'cnt-top-bridges', 'csv', 'migrated']
# [2025-10-08 20:22:15,395] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\CNT_top_hubs.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__cnt-top-hubs__c508a665.csv   tags=['cnt', 'cnt-top-hubs', 'csv', 'migrated']
# [2025-10-08 20:22:15,424] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\Genomotry.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__genomotry__ffb2f03c.ipynb   tags=['genomotry', 'ipynb', 'migrated']
# [2025-10-08 20:22:15,433] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\glyph_raytrace_preview.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__glyph-raytrace-preview__6c15c3e6.png   tags=['glyph-raytrace-preview', 'migrated', 'png']
# [2025-10-08 20:22:15,437] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\iCNT_Atlas_AllInOne.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__icnt-atlas-allinone__0bb7b059.ipynb   tags=['atlas', 'cnt', 'icnt-atlas-allinone', 'ipynb', 'migrated']
# [2025-10-08 20:22:15,450] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\iCNT_Testbed.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__icnt-testbed__1c36cfad.ipynb   tags=['cnt', 'icnt-testbed', 'ipynb', 'migrated']
# [2025-10-08 20:22:15,463] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\iCNT_Testbed2.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__icnt-testbed2__f7ffe2ad.ipynb   tags=['cnt', 'icnt-testbed2', 'ipynb', 'migrated']
# [2025-10-08 20:22:15,475] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\iCNT_Ultimate.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__icnt-ultimate__532f2cfe.ipynb   tags=['cnt', 'icnt-ultimate', 'ipynb', 'migrated']
# [2025-10-08 20:22:15,503] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\Outer Wilds OST - Travelers (All Instruments Join).mp4  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__outer-wilds-ost-travelers-all-instruments-join__e6cde8f3.mp4   tags=['migrated', 'mp4', 'outer-wilds-ost-travelers-all-instruments-join']
# [2025-10-08 20:22:15,522] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\Untitled.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__untitled__eec926f4.ipynb   tags=['ipynb', 'migrated', 'untitled']
# [2025-10-08 20:22:15,532] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\Untitled1.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__untitled1__5280e99d.ipynb   tags=['ipynb', 'migrated', 'untitled1']
# [2025-10-08 20:22:15,546] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\Untitled2.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__untitled2__399e27db.ipynb   tags=['ipynb', 'migrated', 'untitled2']
# [2025-10-08 20:22:15,549] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\Untitled3.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__untitled3__b41e2681.ipynb   tags=['ipynb', 'migrated', 'untitled3']
# [2025-10-08 20:22:15,559] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\Untitled4.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__untitled4__663766ff.ipynb   tags=['ipynb', 'migrated', 'untitled4']
# [2025-10-08 20:22:15,570] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\Untitled5.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__untitled5__70f494e0.ipynb   tags=['ipynb', 'migrated', 'untitled5']
# [2025-10-08 20:22:15,587] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\Untitled6.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__untitled6__dbcaacb3.ipynb   tags=['ipynb', 'migrated', 'untitled6']
# [2025-10-08 20:22:15,603] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\Untitled7.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__untitled7__b55bc524.ipynb   tags=['ipynb', 'migrated', 'untitled7']
# [2025-10-08 20:22:15,698] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\Untitled8.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__untitled8__07549cce.ipynb   tags=['ipynb', 'migrated', 'untitled8']
# [2025-10-08 20:22:15,716] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves\S001R01.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s001r01__4743b736.edf   tags=['brainwaves', 'edf', 'migrated', 's001r01']
# [2025-10-08 20:22:15,732] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves\S001R02.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s001r02__31a95e0a.edf   tags=['brainwaves', 'edf', 'migrated', 's001r02']
# [2025-10-08 20:22:15,752] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves\S001R03.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s001r03__3427c8d0.edf   tags=['brainwaves', 'edf', 'migrated', 's001r03']
# [2025-10-08 20:22:15,772] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves\S001R04.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s001r04__5369364f.edf   tags=['brainwaves', 'edf', 'migrated', 's001r04']
# [2025-10-08 20:22:15,797] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves\S001R05.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s001r05__8828f4b9.edf   tags=['brainwaves', 'edf', 'migrated', 's001r05']
# [2025-10-08 20:22:15,823] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves\S001R07.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s001r07__6320a941.edf   tags=['brainwaves', 'edf', 'migrated', 's001r07']
# [2025-10-08 20:22:15,840] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves\S001R08.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s001r08__358fb518.edf   tags=['brainwaves', 'edf', 'migrated', 's001r08']
# [2025-10-08 20:22:15,859] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves\S001R09.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s001r09__1b642457.edf   tags=['brainwaves', 'edf', 'migrated', 's001r09']
# [2025-10-08 20:22:15,878] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\brainwaves\sim_alpha.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__sim-alpha__f44f6f05.csv   tags=['brainwaves', 'csv', 'migrated', 'sim-alpha']
# [2025-10-08 20:22:15,894] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\brainwaves\sim_theta.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__sim-theta__fc536f2f.csv   tags=['brainwaves', 'csv', 'migrated', 'sim-theta']
# [2025-10-08 20:22:15,923] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S001_S001R10.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s001-s001r10__20de1c77.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's001-s001r10']
# [2025-10-08 20:22:15,940] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S001_S001R13.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s001-s001r13__dde64623.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's001-s001r13']
# [2025-10-08 20:22:15,958] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S001_S001R14.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s001-s001r14__2110c48e.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's001-s001r14']
# [2025-10-08 20:22:15,975] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S002_S002R05.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s002-s002r05__16ad84f1.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's002-s002r05']
# [2025-10-08 20:22:15,992] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S002_S002R06.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s002-s002r06__08b07a84.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's002-s002r06']
# [2025-10-08 20:22:16,008] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S002_S002R09.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s002-s002r09__bc439584.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's002-s002r09']
# [2025-10-08 20:22:16,026] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S002_S002R10.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s002-s002r10__817961f2.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's002-s002r10']
# [2025-10-08 20:22:16,042] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S002_S002R13.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s002-s002r13__6c018440.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's002-s002r13']
# [2025-10-08 20:22:16,059] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S002_S002R14.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s002-s002r14__21e20c72.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's002-s002r14']
# [2025-10-08 20:22:16,075] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S003_S003R05.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s003-s003r05__847632c5.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's003-s003r05']
# [2025-10-08 20:22:16,095] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S003_S003R06.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s003-s003r06__8d48a463.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's003-s003r06']
# [2025-10-08 20:22:16,117] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S003_S003R09.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s003-s003r09__e871d2d8.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's003-s003r09']
# [2025-10-08 20:22:16,136] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S003_S003R10.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s003-s003r10__99429f00.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's003-s003r10']
# [2025-10-08 20:22:16,156] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S003_S003R13.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s003-s003r13__db14ae5f.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's003-s003r13']
# [2025-10-08 20:22:16,174] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S003_S003R14.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s003-s003r14__c80a7a0f.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's003-s003r14']
# [2025-10-08 20:22:16,195] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S004_S004R05.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s004-s004r05__03d587f2.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's004-s004r05']
# [2025-10-08 20:22:16,215] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S004_S004R06.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s004-s004r06__2d9afd10.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's004-s004r06']
# [2025-10-08 20:22:16,232] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S004_S004R09.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s004-s004r09__2b5b61af.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's004-s004r09']
# [2025-10-08 20:22:16,250] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S004_S004R10.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s004-s004r10__8f803425.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's004-s004r10']
# [2025-10-08 20:22:16,266] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S004_S004R13.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s004-s004r13__136e362b.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's004-s004r13']
# [2025-10-08 20:22:16,283] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S004_S004R14.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s004-s004r14__06a3c882.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's004-s004r14']
# [2025-10-08 20:22:16,303] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S005_S005R05.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s005-s005r05__40ab4f0b.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's005-s005r05']
# [2025-10-08 20:22:16,321] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S005_S005R06.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s005-s005r06__07260f0b.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's005-s005r06']
# [2025-10-08 20:22:16,337] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S005_S005R09.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s005-s005r09__bdc00722.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's005-s005r09']
# [2025-10-08 20:22:16,360] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S005_S005R10.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s005-s005r10__a5721f5a.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's005-s005r10']
# [2025-10-08 20:22:16,380] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S005_S005R13.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s005-s005r13__2012101a.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's005-s005r13']
# [2025-10-08 20:22:16,401] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S005_S005R14.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s005-s005r14__77d5b9b1.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's005-s005r14']
# [2025-10-08 20:22:16,422] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S006_S006R05.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s006-s006r05__2b793afa.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's006-s006r05']
# [2025-10-08 20:22:16,441] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S006_S006R06.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s006-s006r06__fc5e1cc2.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's006-s006r06']
# [2025-10-08 20:22:16,458] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S006_S006R09.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s006-s006r09__cb3af5f1.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's006-s006r09']
# [2025-10-08 20:22:16,474] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S006_S006R10.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s006-s006r10__d4a1d432.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's006-s006r10']
# [2025-10-08 20:22:16,490] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S006_S006R13.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s006-s006r13__d4ebe044.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's006-s006r13']
# [2025-10-08 20:22:16,507] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S006_S006R14.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s006-s006r14__4fb5946e.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's006-s006r14']
# [2025-10-08 20:22:16,524] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S007_S007R05.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s007-s007r05__6697e3a1.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's007-s007r05']
# [2025-10-08 20:22:16,542] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S007_S007R06.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s007-s007r06__9f6e8d23.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's007-s007r06']
# [2025-10-08 20:22:16,562] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S007_S007R09.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s007-s007r09__47aed2ff.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's007-s007r09']
# [2025-10-08 20:22:16,586] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S007_S007R10.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s007-s007r10__acd9571b.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's007-s007r10']
# [2025-10-08 20:22:16,608] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S007_S007R13.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s007-s007r13__89c78f89.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's007-s007r13']
# [2025-10-08 20:22:16,625] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S007_S007R14.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s007-s007r14__d6245b9b.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's007-s007r14']
# [2025-10-08 20:22:16,642] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S008_S008R05.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s008-s008r05__4a1005e7.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's008-s008r05']
# [2025-10-08 20:22:16,658] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S008_S008R06.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s008-s008r06__c2afadf0.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's008-s008r06']
# [2025-10-08 20:22:16,675] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S008_S008R09.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s008-s008r09__a13ed843.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's008-s008r09']
# [2025-10-08 20:22:16,696] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S008_S008R10.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s008-s008r10__6a7934c1.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's008-s008r10']
# [2025-10-08 20:22:16,713] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S008_S008R13.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s008-s008r13__9707099f.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's008-s008r13']
# [2025-10-08 20:22:16,734] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S008_S008R14.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s008-s008r14__19c943fb.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's008-s008r14']
# [2025-10-08 20:22:16,751] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S009_S009R05.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s009-s009r05__6ecfb972.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's009-s009r05']
# [2025-10-08 20:22:16,768] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S009_S009R06.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s009-s009r06__c6665f0c.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's009-s009r06']
# [2025-10-08 20:22:16,789] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S009_S009R09.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s009-s009r09__33060662.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's009-s009r09']
# [2025-10-08 20:22:16,808] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S009_S009R10.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s009-s009r10__eeeeb3a1.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's009-s009r10']
# [2025-10-08 20:22:16,826] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S009_S009R13.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s009-s009r13__af39afa6.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's009-s009r13']
# [2025-10-08 20:22:16,844] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S009_S009R14.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s009-s009r14__e9ffb381.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's009-s009r14']
# [2025-10-08 20:22:16,863] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S010_S010R05.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s010-s010r05__e83d0bcd.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's010-s010r05']
# [2025-10-08 20:22:16,883] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S010_S010R06.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s010-s010r06__5f5c213f.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's010-s010r06']
# [2025-10-08 20:22:16,900] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S010_S010R09.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s010-s010r09__91bcc4d9.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's010-s010r09']
# [2025-10-08 20:22:16,918] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S010_S010R10.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s010-s010r10__693b0d92.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's010-s010r10']
# [2025-10-08 20:22:16,935] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S010_S010R13.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s010-s010r13__10e642cf.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's010-s010r13']
# [2025-10-08 20:22:16,953] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\brainwaves_multi\S010_S010R14.edf  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__s010-s010r14__138893d9.edf   tags=['brainwaves-multi', 'edf', 'migrated', 's010-s010r14']
# [2025-10-08 20:22:16,962] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_flow_exports\consensus_adjacency.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__consensus-adjacency__1ec6d08f.png   tags=['cnt', 'cnt-flow-exports', 'consensus-adjacency', 'migrated', 'png']
# [2025-10-08 20:22:16,966] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\cnt_flow_exports\consensus_edges.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__consensus-edges__e1c1e785.csv   tags=['cnt', 'cnt-flow-exports', 'consensus-edges', 'csv', 'migrated']
# [2025-10-08 20:22:16,976] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_flow_exports\edges_per_band.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__edges-per-band__350f339d.png   tags=['cnt', 'cnt-flow-exports', 'edges-per-band', 'migrated', 'png']
# [2025-10-08 20:22:16,991] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\cnt_flow_exports\per_band_edges.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__per-band-edges__17075f5c.csv   tags=['cnt', 'cnt-flow-exports', 'csv', 'migrated', 'per-band-edges']
# [2025-10-08 20:22:16,997] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_MASTER\CNT_MASTER\README.md  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__readme__111c72c3.md   tags=['cnt', 'cnt-master', 'md', 'migrated', 'readme']
# [2025-10-08 20:22:17,003] INFO migrate: COPY metrics C:\Users\caleb\cnt_genome\CNT_MASTER\CNT_MASTER\config\omni_config.json  ->  C:\Users\caleb\CNT_Lab\artifacts\metrics\migrated__omni-config__dc9d5a0b.json   tags=['cnt', 'cnt-master', 'config', 'json', 'migrated']
# [2025-10-08 20:22:17,008] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_MASTER\CNT_MASTER\scripts\common.py  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__common__729ca4a0.py   tags=['cnt', 'cnt-master', 'migrated', 'py', 'scripts']
# [2025-10-08 20:22:17,022] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_MASTER\CNT_MASTER\scripts\run_all.bat  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__run-all__589f2a5a.bat   tags=['bat', 'cnt', 'cnt-master', 'migrated', 'scripts']
# [2025-10-08 20:22:17,028] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_MASTER\CNT_MASTER\scripts\run_all.ps1  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__run-all__6aac96aa.ps1   tags=['cnt', 'cnt-master', 'migrated', 'ps1', 'scripts']
# [2025-10-08 20:22:17,033] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_MASTER\CNT_MASTER\scripts\run_manifest.py  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__run-manifest__fb19937f.py   tags=['cnt', 'cnt-master', 'migrated', 'py', 'scripts']
# [2025-10-08 20:22:17,047] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_MASTER\CNT_MASTER\scripts\run_omni.py  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__run-omni__a767f99e.py   tags=['cnt', 'cnt-master', 'migrated', 'py', 'scripts']
# [2025-10-08 20:22:17,052] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_MASTER\CNT_MASTER\scripts\run_prereg.py  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__run-prereg__a2a19462.py   tags=['cnt', 'cnt-master', 'migrated', 'py', 'scripts']
# [2025-10-08 20:22:17,065] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\CNT_MASTER\out\omni_dashboard.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__omni-dashboard__23035750.png   tags=['cnt', 'cnt-master', 'migrated', 'omni-dashboard', 'out', 'png']
# [2025-10-08 20:22:17,071] INFO migrate: COPY metrics C:\Users\caleb\cnt_genome\CNT_MASTER\out\omni_manifest.json  ->  C:\Users\caleb\CNT_Lab\artifacts\metrics\migrated__omni-manifest__5c4359a7.json   tags=['cnt', 'cnt-master', 'json', 'migrated', 'omni-manifest', 'out']
# [2025-10-08 20:22:17,082] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\CNT_MASTER\out\omni_perfile.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__omni-perfile__f770dc3e.csv   tags=['cnt', 'cnt-master', 'csv', 'migrated', 'omni-perfile', 'out']
# [2025-10-08 20:22:17,086] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_MASTER\out\omni_prereg.txt  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__omni-prereg__78fa3ff6.txt   tags=['cnt', 'cnt-master', 'migrated', 'omni-prereg', 'out', 'txt']
# [2025-10-08 20:22:17,089] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\CNT_MASTER\out\omni_prereg_ascii.txt  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__omni-prereg-ascii__56cb70cd.txt   tags=['cnt', 'cnt-master', 'migrated', 'omni-prereg-ascii', 'out', 'txt']
# [2025-10-08 20:22:17,092] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\CNT_MASTER\out\omni_summary.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__omni-summary__d85bc4d7.csv   tags=['cnt', 'cnt-master', 'csv', 'migrated', 'omni-summary', 'out']
# [2025-10-08 20:22:17,096] INFO migrate: COPY metrics C:\Users\caleb\cnt_genome\CNT_MASTER\out\omni_summary.json  ->  C:\Users\caleb\CNT_Lab\artifacts\metrics\migrated__omni-summary__1ecd150d.json   tags=['cnt', 'cnt-master', 'json', 'migrated', 'omni-summary', 'out']
# [2025-10-08 20:22:17,112] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_mega_out\CNT_Mega_Proof.pdf  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-mega-proof__32f83d78.pdf   tags=['cnt', 'cnt-mega-out', 'cnt-mega-proof', 'mega', 'migrated', 'pdf']
# [2025-10-08 20:22:17,124] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_mega_out\ising_fss_beta_over_nu.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__ising-fss-beta-over-nu__36ef5050.png   tags=['cnt', 'cnt-mega-out', 'fss', 'ising', 'ising-fss-beta-over-nu', 'mega', 'migrated', 'png']
# [2025-10-08 20:22:17,135] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_mega_out\kuramoto_beta_fit.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__kuramoto-beta-fit__6c8cafe5.png   tags=['cnt', 'cnt-mega-out', 'kuramoto', 'kuramoto-beta-fit', 'mega', 'migrated', 'png']
# [2025-10-08 20:22:17,146] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_mega_out\tdgl_relax.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__tdgl-relax__ad681a8d.png   tags=['cnt', 'cnt-mega-out', 'mega', 'migrated', 'png', 'tdgl-relax']
# [2025-10-08 20:22:17,157] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_mega_out\topo_edge_grayscott.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__topo-edge-grayscott__9de65aac.png   tags=['cnt', 'cnt-mega-out', 'mega', 'migrated', 'png', 'topo', 'topo-edge-grayscott']
# [2025-10-08 20:22:17,168] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_mega_out\topo_edge_kuramoto.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__topo-edge-kuramoto__3507c2f7.png   tags=['cnt', 'cnt-mega-out', 'kuramoto', 'mega', 'migrated', 'png', 'topo', 'topo-edge-kuramoto']
# [2025-10-08 20:22:17,180] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_mega_out_patch\grayscott_edge_scan.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__grayscott-edge-scan__4ffa8ed2.png   tags=['cnt', 'cnt-mega-out-patch', 'grayscott-edge-scan', 'mega', 'migrated', 'png']
# [2025-10-08 20:22:17,191] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_mega_out_patch\ising_wolff_binder_tc.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__ising-wolff-binder-tc__3036541d.png   tags=['cnt', 'cnt-mega-out-patch', 'ising', 'ising-wolff-binder-tc', 'mega', 'migrated', 'png']
# [2025-10-08 20:22:17,202] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_mega_out_patch\ising_wolff_fss.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__ising-wolff-fss__b01c52d9.png   tags=['cnt', 'cnt-mega-out-patch', 'fss', 'ising', 'ising-wolff-fss', 'mega', 'migrated', 'png']
# [2025-10-08 20:22:17,214] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_mega_out_patch\kuramoto_refined_beta.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__kuramoto-refined-beta__6e01fb19.png   tags=['cnt', 'cnt-mega-out-patch', 'kuramoto', 'kuramoto-refined-beta', 'mega', 'migrated', 'png']
# [2025-10-08 20:22:17,219] INFO migrate: COPY metrics C:\Users\caleb\cnt_genome\cnt_mega_out_patch\metrics.json  ->  C:\Users\caleb\CNT_Lab\artifacts\metrics\migrated__metrics__34768959.json   tags=['cnt', 'cnt-mega-out-patch', 'json', 'mega', 'metrics', 'migrated']
# [2025-10-08 20:22:17,230] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_phase_exports\cnt_curvature_overlay.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-curvature-overlay__8251299c.png   tags=['cnt', 'cnt-curvature-overlay', 'cnt-phase-exports', 'migrated', 'png']
# [2025-10-08 20:22:17,238] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_phase_exports\cnt_curvature_overlay_with_real.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-curvature-overlay-with-real__bf3d1de3.png   tags=['cnt', 'cnt-curvature-overlay-with-real', 'cnt-phase-exports', 'migrated', 'png']
# [2025-10-08 20:22:17,242] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\cnt_phase_exports\cnt_phase_report.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__cnt-phase-report__ff3a37a5.csv   tags=['cnt', 'cnt-phase-exports', 'cnt-phase-report', 'csv', 'migrated']
# [2025-10-08 20:22:17,255] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_polish_out\ising_wolff_binder_tc.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__ising-wolff-binder-tc__a7c3db5b.png   tags=['cnt', 'cnt-polish-out', 'ising', 'ising-wolff-binder-tc', 'migrated', 'png']
# [2025-10-08 20:22:17,267] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_polish_out\ising_wolff_fss.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__ising-wolff-fss__44b6094d.png   tags=['cnt', 'cnt-polish-out', 'fss', 'ising', 'ising-wolff-fss', 'migrated', 'png']
# [2025-10-08 20:22:17,280] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_polish_out\kuramoto_sigma0_beta.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__kuramoto-sigma0-beta__67ef0346.png   tags=['cnt', 'cnt-polish-out', 'kuramoto', 'kuramoto-sigma0-beta', 'migrated', 'png']
# [2025-10-08 20:22:17,291] INFO migrate: COPY metrics C:\Users\caleb\cnt_genome\cnt_polish_out\metrics.json  ->  C:\Users\caleb\CNT_Lab\artifacts\metrics\migrated__metrics__66243803.json   tags=['cnt', 'cnt-polish-out', 'json', 'metrics', 'migrated']
# [2025-10-08 20:22:17,304] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_proof_out\cnt_grayscott_pattern.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-grayscott-pattern__0db697cb.png   tags=['cnt', 'cnt-grayscott-pattern', 'cnt-proof-out', 'migrated', 'png']
# [2025-10-08 20:22:17,316] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_proof_out\cnt_grayscott_uniformish.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-grayscott-uniformish__a7b7bb90.png   tags=['cnt', 'cnt-grayscott-uniformish', 'cnt-proof-out', 'migrated', 'png']
# [2025-10-08 20:22:17,326] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_proof_out\cnt_ising_mtrace.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-ising-mtrace__0f460d32.png   tags=['cnt', 'cnt-ising-mtrace', 'cnt-proof-out', 'ising', 'migrated', 'png']
# [2025-10-08 20:22:17,338] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_proof_out\cnt_kuramoto_ecdf.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-kuramoto-ecdf__37442d0e.png   tags=['cnt', 'cnt-kuramoto-ecdf', 'cnt-proof-out', 'kuramoto', 'migrated', 'png']
# [2025-10-08 20:22:17,353] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_proof_out\CNT_Physics_Proof_local.pdf  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__cnt-physics-proof-local__b0aaf8fb.pdf   tags=['cnt', 'cnt-physics-proof-local', 'cnt-proof-out', 'migrated', 'pdf']
# [2025-10-08 20:22:17,364] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_proof_out\grayscott_betti0_auc.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__grayscott-betti0-auc__12559385.png   tags=['cnt', 'cnt-proof-out', 'grayscott-betti0-auc', 'migrated', 'png']
# [2025-10-08 20:22:17,376] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_proof_out\grayscott_betti1_auc.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__grayscott-betti1-auc__ab3c527e.png   tags=['cnt', 'cnt-proof-out', 'grayscott-betti1-auc', 'migrated', 'png']
# [2025-10-08 20:22:17,385] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_proof_out\grayscott_lacunarity_bar.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__grayscott-lacunarity-bar__818ced6a.png   tags=['cnt', 'cnt-proof-out', 'grayscott-lacunarity-bar', 'migrated', 'png']
# [2025-10-08 20:22:17,395] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_proof_out\grayscott_phase_entropy.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__grayscott-phase-entropy__d416de8f.png   tags=['cnt', 'cnt-proof-out', 'grayscott-phase-entropy', 'migrated', 'png']
# [2025-10-08 20:22:17,406] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_proof_out\grayscott_phase_sigma.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__grayscott-phase-sigma__2cfb714e.png   tags=['cnt', 'cnt-proof-out', 'grayscott-phase-sigma', 'migrated', 'png']
# [2025-10-08 20:22:17,416] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_proof_out\ising_binder_collapse.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__ising-binder-collapse__c0de9194.png   tags=['cnt', 'cnt-proof-out', 'ising', 'ising-binder-collapse', 'migrated', 'png']
# [2025-10-08 20:22:17,427] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_proof_out\ising_binder_crossing.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__ising-binder-crossing__ac939447.png   tags=['cnt', 'cnt-proof-out', 'ising', 'ising-binder-crossing', 'migrated', 'png']
# [2025-10-08 20:22:17,442] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\cnt_proof_out\kuramoto_Kc_extrapolation.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__kuramoto-kc-extrapolation__1b74e6cc.png   tags=['cnt', 'cnt-proof-out', 'kuramoto', 'kuramoto-kc-extrapolation', 'migrated', 'png']
# ...
# [2025-10-08 20:22:35,357] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out\erd_S001R03.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__erd-s001r03__7501f7c7.png   tags=['erd-s001r03', 'migrated', 'out', 'png']
# [2025-10-08 20:22:35,370] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out\final_invariance_figure.pdf  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__final-invariance-figure__e727f0f1.pdf   tags=['final-invariance-figure', 'migrated', 'out', 'pdf']
# [2025-10-08 20:22:35,374] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\out\gEDE_best_curve.npy  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__gede-best-curve__74444f87.npy   tags=['gede-best-curve', 'migrated', 'npy', 'out']
# [2025-10-08 20:22:35,377] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\out\gEDE_best_curve_v2.npy  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__gede-best-curve-v2__67e1b04f.npy   tags=['gede-best-curve-v2', 'migrated', 'npy', 'out']
# [2025-10-08 20:22:35,392] INFO migrate: COPY model   C:\Users\caleb\cnt_genome\out\gEDE_chi2_grid.npz  ->  C:\Users\caleb\CNT_Lab\artifacts\models\migrated__gede-chi2-grid__646af05c.npz   tags=['gede-chi2-grid', 'migrated', 'npz', 'out']
# [2025-10-08 20:22:35,408] INFO migrate: COPY model   C:\Users\caleb\cnt_genome\out\gEDE_chi2_grid_v2.npz  ->  C:\Users\caleb\CNT_Lab\artifacts\models\migrated__gede-chi2-grid-v2__764cb979.npz   tags=['gede-chi2-grid-v2', 'migrated', 'npz', 'out']
# [2025-10-08 20:22:35,412] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\out\methods_release.md  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__methods-release__31871edc.md   tags=['md', 'methods-release', 'migrated', 'out']
# [2025-10-08 20:22:35,415] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\out\methods_release.tex  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__methods-release__a2fc248e.tex   tags=['methods-release', 'migrated', 'out', 'tex']
# [2025-10-08 20:22:35,418] INFO migrate: COPY metrics C:\Users\caleb\cnt_genome\out\seq_adaptive_pelt.json  ->  C:\Users\caleb\CNT_Lab\artifacts\metrics\migrated__seq-adaptive-pelt__c946951c.json   tags=['json', 'migrated', 'out', 'seq-adaptive-pelt']
# [2025-10-08 20:22:35,428] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out\seq_adaptive_pelt_fig.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__seq-adaptive-pelt-fig__ebcdc058.png   tags=['migrated', 'out', 'png', 'seq-adaptive-pelt-fig']
# [2025-10-08 20:22:35,432] INFO migrate: COPY metrics C:\Users\caleb\cnt_genome\out\seq_cnt_report_fixed.json  ->  C:\Users\caleb\CNT_Lab\artifacts\metrics\migrated__seq-cnt-report-fixed__da58ac4a.json   tags=['cnt', 'json', 'migrated', 'out', 'seq-cnt-report-fixed']
# [2025-10-08 20:22:35,443] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\out\seq_gc_windows_1Mb.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__seq-gc-windows-1mb__d66afd19.csv   tags=['csv', 'migrated', 'out', 'seq-gc-windows-1mb']
# [2025-10-08 20:22:35,452] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out\seq_local_moran_fig.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__seq-local-moran-fig__ad567c92.png   tags=['migrated', 'out', 'png', 'seq-local-moran-fig']
# [2025-10-08 20:22:35,462] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out\seq_moran_200kb.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__seq-moran-200kb__47d91790.png   tags=['migrated', 'out', 'png', 'seq-moran-200kb']
# [2025-10-08 20:22:35,471] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out\seq_pelt_200kb.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__seq-pelt-200kb__089840a7.png   tags=['migrated', 'out', 'png', 'seq-pelt-200kb']
# [2025-10-08 20:22:35,482] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out\seq_reality_vs_shuffle_fixed.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__seq-reality-vs-shuffle-fixed__a3843a9c.png   tags=['migrated', 'out', 'png', 'seq-reality-vs-shuffle-fixed']
# [2025-10-08 20:22:35,491] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out\seq_resilience.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__seq-resilience__434856b1.png   tags=['migrated', 'out', 'png', 'seq-resilience']
# [2025-10-08 20:22:35,501] INFO migrate: COPY metrics C:\Users\caleb\cnt_genome\out\seq_spatial_cnt.json  ->  C:\Users\caleb\CNT_Lab\artifacts\metrics\migrated__seq-spatial-cnt__b3045007.json   tags=['cnt', 'json', 'migrated', 'out', 'seq-spatial-cnt']
# [2025-10-08 20:22:35,516] INFO migrate: COPY metrics C:\Users\caleb\cnt_genome\out\seq_spatial_cnt_200kb.json  ->  C:\Users\caleb\CNT_Lab\artifacts\metrics\migrated__seq-spatial-cnt-200kb__20d51ee7.json   tags=['cnt', 'json', 'migrated', 'out', 'seq-spatial-cnt-200kb']
# [2025-10-08 20:22:35,528] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out\seq_spatial_cnt_hists.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__seq-spatial-cnt-hists__cb3cd032.png   tags=['cnt', 'migrated', 'out', 'png', 'seq-spatial-cnt-hists']
# [2025-10-08 20:22:35,538] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out\seq_spatial_cnt_summary.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__seq-spatial-cnt-summary__721f614e.png   tags=['cnt', 'migrated', 'out', 'png', 'seq-spatial-cnt-summary']
# [2025-10-08 20:22:35,547] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out\seq_stability_ari_fixed.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__seq-stability-ari-fixed__639d202b.png   tags=['migrated', 'out', 'png', 'seq-stability-ari-fixed']
# [2025-10-08 20:22:35,550] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\out\summary.txt  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__summary__af94d48a.txt   tags=['migrated', 'out', 'summary', 'txt']
# [2025-10-08 20:22:35,553] INFO migrate: COPY metrics C:\Users\caleb\cnt_genome\out\summary_dual_path.json  ->  C:\Users\caleb\CNT_Lab\artifacts\metrics\migrated__summary-dual-path__3386edc9.json   tags=['json', 'migrated', 'out', 'summary-dual-path']
# [2025-10-08 20:22:35,563] INFO migrate: COPY metrics C:\Users\caleb\cnt_genome\out\summary_dual_path_v2.json  ->  C:\Users\caleb\CNT_Lab\artifacts\metrics\migrated__summary-dual-path-v2__1ecae137.json   tags=['json', 'migrated', 'out', 'summary-dual-path-v2']
# [2025-10-08 20:22:35,581] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out\field_note_Dermatitis\layered.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__layered__0e934645.png   tags=['field-note-dermatitis', 'layered', 'migrated', 'out', 'png']
# [2025-10-08 20:22:36,654] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\out\field_note_Dermatitis\network_3D.html  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__network-3d__bc5e2d3e.html   tags=['field-note-dermatitis', 'html', 'migrated', 'network-3d', 'out']
# [2025-10-08 20:22:36,658] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\out\field_note_Dermatitis\README.md  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__readme__0ba65475.md   tags=['field-note-dermatitis', 'md', 'migrated', 'out', 'readme']
# [2025-10-08 20:22:36,668] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\out\field_note_Dermatitis\table.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__table__5cca9e02.csv   tags=['csv', 'field-note-dermatitis', 'migrated', 'out', 'table']
# [2025-10-08 20:22:36,670] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\out\field_note_Dermatitis\top_ccres.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__top-ccres__e6cb3697.csv   tags=['csv', 'field-note-dermatitis', 'migrated', 'out', 'top-ccres']
# [2025-10-08 20:22:36,673] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\out\field_note_Dermatitis\top_genes.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__top-genes__78c478bd.csv   tags=['csv', 'field-note-dermatitis', 'migrated', 'out', 'top-genes']
# [2025-10-08 20:22:36,688] INFO migrate: COPY table   C:\Users\caleb\cnt_genome\out\mini_atlas_lipids\table.csv  ->  C:\Users\caleb\CNT_Lab\artifacts\tables\migrated__table__82e92e55.csv   tags=['atlas', 'csv', 'migrated', 'mini-atlas-lipids', 'out', 'table']
# [2025-10-08 20:22:36,704] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\outputs\area_slice_b0.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__area-slice-b0__e15f869d.png   tags=['area-slice-b0', 'migrated', 'outputs', 'png']
# [2025-10-08 20:22:36,713] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\outputs\area_slice_b2.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__area-slice-b2__3d0f1f98.png   tags=['area-slice-b2', 'migrated', 'outputs', 'png']
# [2025-10-08 20:22:36,722] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\outputs\area_slice_b4.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__area-slice-b4__bab87ceb.png   tags=['area-slice-b4', 'migrated', 'outputs', 'png']
# [2025-10-08 20:22:36,727] INFO migrate: COPY metrics C:\Users\caleb\cnt_genome\outputs\atlas_mapping.json  ->  C:\Users\caleb\CNT_Lab\artifacts\metrics\migrated__atlas-mapping__00974f13.json   tags=['atlas', 'atlas-mapping', 'json', 'migrated', 'outputs']
# [2025-10-08 20:22:36,736] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\outputs\finalphi_slice_b0.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__finalphi-slice-b0__5acf9dd7.png   tags=['finalphi-slice-b0', 'migrated', 'outputs', 'png']
# [2025-10-08 20:22:36,745] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\outputs\finalphi_slice_b2.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__finalphi-slice-b2__9f5800ed.png   tags=['finalphi-slice-b2', 'migrated', 'outputs', 'png']
# [2025-10-08 20:22:36,753] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\outputs\finalphi_slice_b4.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__finalphi-slice-b4__d147759c.png   tags=['finalphi-slice-b4', 'migrated', 'outputs', 'png']
# [2025-10-08 20:22:36,762] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\outputs\fracprob_slice_b0.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__fracprob-slice-b0__3cf89eb4.png   tags=['fracprob-slice-b0', 'migrated', 'outputs', 'png']
# [2025-10-08 20:22:36,770] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\outputs\fracprob_slice_b2.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__fracprob-slice-b2__c0aaa2a5.png   tags=['fracprob-slice-b2', 'migrated', 'outputs', 'png']
# [2025-10-08 20:22:36,779] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\outputs\fracprob_slice_b4.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__fracprob-slice-b4__0b21bc76.png   tags=['fracprob-slice-b4', 'migrated', 'outputs', 'png']
# [2025-10-08 20:22:36,783] INFO migrate: COPY metrics C:\Users\caleb\cnt_genome\outputs\lab_card.json  ->  C:\Users\caleb\CNT_Lab\artifacts\metrics\migrated__lab-card__8a310cdb.json   tags=['json', 'lab-card', 'migrated', 'outputs']
# [2025-10-08 20:22:36,798] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\outputs\phi_real.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__phi-real__4182737c.png   tags=['migrated', 'outputs', 'phi-real', 'png']
# [2025-10-08 20:22:36,809] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\outputs\psi_real.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__psi-real__2b0482fc.png   tags=['migrated', 'outputs', 'png', 'psi-real']
# [2025-10-08 20:22:36,812] INFO migrate: COPY metrics C:\Users\caleb\cnt_genome\outputs\real_fracture_metrics.json  ->  C:\Users\caleb\CNT_Lab\artifacts\metrics\migrated__real-fracture-metrics__5c903ae1.json   tags=['json', 'migrated', 'outputs', 'real-fracture-metrics']
# [2025-10-08 20:22:36,814] INFO migrate: COPY blob    C:\Users\caleb\cnt_genome\outputs\Untitled.ipynb  ->  C:\Users\caleb\CNT_Lab\artifacts\migrated__untitled__fb9635e0.ipynb   tags=['ipynb', 'migrated', 'outputs', 'untitled']
# [2025-10-08 20:22:36,824] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out_proof\grayscott_phase_entropy.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__grayscott-phase-entropy__f32b2ef0.png   tags=['grayscott-phase-entropy', 'migrated', 'out-proof', 'png']
# [2025-10-08 20:22:36,832] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out_proof\grayscott_phase_sigma.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__grayscott-phase-sigma__2c3bfa0a.png   tags=['grayscott-phase-sigma', 'migrated', 'out-proof', 'png']
# [2025-10-08 20:22:36,841] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out_proof\ising_binder_crossing.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__ising-binder-crossing__c250b784.png   tags=['ising', 'ising-binder-crossing', 'migrated', 'out-proof', 'png']
# [2025-10-08 20:22:36,849] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out_proof\kuramoto_mean_r_vs_K.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__kuramoto-mean-r-vs-k__6045cef0.png   tags=['kuramoto', 'kuramoto-mean-r-vs-k', 'migrated', 'out-proof', 'png']
# [2025-10-08 20:22:36,858] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out_proof\kuramoto_susceptibility_vs_K.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__kuramoto-susceptibility-vs-k__8b5fbc03.png   tags=['kuramoto', 'kuramoto-susceptibility-vs-k', 'migrated', 'out-proof', 'png']
# [2025-10-08 20:22:36,868] INFO migrate: COPY metrics C:\Users\caleb\cnt_genome\out_proof\proof_summary.json  ->  C:\Users\caleb\CNT_Lab\artifacts\metrics\migrated__proof-summary__7dc7efeb.json   tags=['json', 'migrated', 'out-proof', 'proof-summary']
# [2025-10-08 20:22:36,882] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out_proof2\grayscott_betti0_curves.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__grayscott-betti0-curves__052f1ab0.png   tags=['grayscott-betti0-curves', 'migrated', 'out-proof2', 'png']
# [2025-10-08 20:22:36,890] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out_proof2\grayscott_betti1_curves.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__grayscott-betti1-curves__785a0365.png   tags=['grayscott-betti1-curves', 'migrated', 'out-proof2', 'png']
# [2025-10-08 20:22:36,900] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out_proof2\grayscott_euler_bar.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__grayscott-euler-bar__6163d8cb.png   tags=['grayscott-euler-bar', 'migrated', 'out-proof2', 'png']
# [2025-10-08 20:22:36,911] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out_proof2\grayscott_lacunarity_bar.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__grayscott-lacunarity-bar__e9e09179.png   tags=['grayscott-lacunarity-bar', 'migrated', 'out-proof2', 'png']
# [2025-10-08 20:22:36,924] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out_proof2\ising_binder_collapse.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__ising-binder-collapse__347df4b7.png   tags=['ising', 'ising-binder-collapse', 'migrated', 'out-proof2', 'png']
# [2025-10-08 20:22:36,935] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out_proof2\ising_binder_cross_est.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__ising-binder-cross-est__49479bd0.png   tags=['ising', 'ising-binder-cross-est', 'migrated', 'out-proof2', 'png']
# [2025-10-08 20:22:36,945] INFO migrate: COPY figure  C:\Users\caleb\cnt_genome\out_proof2\kuramoto_Kc_extrapolation.png  ->  C:\Users\caleb\CNT_Lab\artifacts\figures\migrated__kuramoto-kc-extrapolation__bd0edbb2.png   tags=['kuramoto', 'kuramoto-kc-extrapolation', 'migrated', 'out-proof2', 'png']
# [2025-10-08 20:22:36,950] INFO migrate: COPY metrics C:\Users\caleb\cnt_genome\out_proof2\proof2_summary.json  ->  C:\Users\caleb\CNT_Lab\artifacts\metrics\migrated__proof2-summary__0029eb2e.json   tags=['json', 'migrated', 'out-proof2', 'proof2-summary']
# Scanning: C:\Users\caleb\cnt_genome
#
# == MIGRATION SUMMARY ==
# scanned       : 1414
# skipped_dupe  : 742
# migrated      : 672
# errors        : 0
# By kind: {'figure': 288, 'table': 95, 'metrics': 101, 'model': 11, 'blob': 177}
# Manifest: C:\Users\caleb\CNT_Lab\artifacts\manifests\manifest.jsonl

# %%
from pathlib import Path
import shutil, cntlab as cl

P = cl.P
dst = P.root / "notebooks" / "archive"
dst.mkdir(parents=True, exist_ok=True)

moved = 0
for p in (P.artifacts).glob("*.ipynb"):
    newp = dst / p.name
    shutil.move(str(p), str(newp))
    cl.manifest.log_artifact(newp, kind="notebook",
                             tags=["migrated","notebook"],
                             meta={"relocated_from": str(p)})
    moved += 1

print(f"Relocated {moved} notebook(s) → {dst}")
# Out:
# Relocated 28 notebook(s) → C:\Users\caleb\CNT_Lab\notebooks\archive

# %%
import pandas as pd, cntlab as cl
rows = []
for k in ["figure","table","metrics","model","notebook","blob"]:
    for rec in cl.manifest.find_artifacts(kind=k):
        rows.append({"kind":k,"path":rec["path"],"tags":";".join(rec["tags"]), "ts":rec["ts"], "size":rec.get("size")})
df = pd.DataFrame(rows).sort_values("ts")
idx_path = cl.io.save_df(df, module="inventory", dataset="all", desc="manifest_index", fmt="csv", tags=["index","manifest"])
print("Index saved →", idx_path)
df.tail(10)
# Out:
# Index saved → C:\Users\caleb\CNT_Lab\artifacts\tables\inventory__all__manifest_index__20251008-202444.csv
#          kind                                               path  \
# 503  notebook  C:\Users\caleb\CNT_Lab\notebooks\archive\migra...
# 502  notebook  C:\Users\caleb\CNT_Lab\notebooks\archive\migra...
# 501  notebook  C:\Users\caleb\CNT_Lab\notebooks\archive\migra...
# 500  notebook  C:\Users\caleb\CNT_Lab\notebooks\archive\migra...
# 498  notebook  C:\Users\caleb\CNT_Lab\notebooks\archive\migra...
# 497  notebook  C:\Users\caleb\CNT_Lab\notebooks\archive\migra...
# 496  notebook  C:\Users\caleb\CNT_Lab\notebooks\archive\migra...
# 495  notebook  C:\Users\caleb\CNT_Lab\notebooks\archive\migra...
# 511  notebook  C:\Users\caleb\CNT_Lab\notebooks\archive\migra...
# 499  notebook  C:\Users\caleb\CNT_Lab\notebooks\archive\migra...
#
#                   tags                    ts    size
# 503  migrated;notebook  2025-10-09T00:24:17Z  438661
# 502  migrated;notebook  2025-10-09T00:24:17Z   37612
# 501  migrated;notebook  2025-10-09T00:24:17Z  450902
# 500  migrated;notebook  2025-10-09T00:24:17Z  257554
# 498  migrated;notebook  2025-10-09T00:24:17Z   17545
# 497  migrated;notebook  2025-10-09T00:24:17Z   21007
# 496  migrated;notebook  2025-10-09T00:24:17Z   31093
# 495  migrated;notebook  2025-10-09T00:24:17Z  134343
# 511  migrated;notebook  2025-10-09T00:24:17Z     617
# 499  migrated;notebook  2025-10-09T00:24:17Z  199733

# %%
# Count by kind
import collections, json, cntlab as cl
cnts = collections.Counter(rec["kind"] for rec in cl.manifest.find_artifacts(kind=None))
cnts

# Find anything with 'resonance'
[x["path"] for x in cl.manifest.find_artifacts(tags_any=["resonance"])][:5]
# Out:
# ['C:\\Users\\caleb\\CNT_Lab\\artifacts\\tables\\migrated__cnt-genomic-resonance-map__df629623.csv',
#  'C:\\Users\\caleb\\CNT_Lab\\artifacts\\tables\\migrated__cnt-genomic-resonance-scored__ab1e21a4.csv',
#  'C:\\Users\\caleb\\CNT_Lab\\artifacts\\tables\\migrated__cnt-genomic-resonance-scored-v2__6c4fb256.csv']
